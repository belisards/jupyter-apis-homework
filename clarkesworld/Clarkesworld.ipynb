# %% [markdown]
# # Clarkesworld
#
# Source: https://clarkesworldmagazine.com/
#
# Description: Sci-fi/fantasy magazine
#
# **Topics:**
#
# * Scraping

# %% [markdown]
# ## Scrape the Clarkesworld homepage `4 points`
#
# I want a CSV file that includes a row for each story, including the columns:
#
# * Title
# * Byline
# * URL to story
# * Category (fiction/non-fiction/cover art)
# * Issue number (e.g. 180)
# * Publication date (e.g. September 2021)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://clarkesworldmagazine.com/'
response = requests.get(url)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
sep = ' – '
issue_date = doc.find(class_='issue').text
issue = issue_date.split(sep)[0]
date = issue_date.split(sep)[1]

print(issue,sep, date)
# Out:
# ISSUE 180  –  September 2021

# %%
rows = []

for section in doc.select('.index-table .index-table'):
    category = section.find(class_='section').text
    for article in section.findAll('div', {'class':['index-col1', 'index-col2']}):
        row = {}
        row['category'] = category
        row['issue'] = issue
        row['date'] = date
        row['title'] = article.find(class_='story').text
        row['byline'] = article.find(class_='byline').text
        row['link'] = article.find('a')['href']
        # print(row)
        rows.append(row)

# %%
df = pd.DataFrame(rows)
df
# Out:
#        category      issue            date  \
# 0       FICTION  ISSUE 180  September 2021
# 1       FICTION  ISSUE 180  September 2021
# 2       FICTION  ISSUE 180  September 2021
# 3       FICTION  ISSUE 180  September 2021
# 4       FICTION  ISSUE 180  September 2021
# 5       FICTION  ISSUE 180  September 2021
# 6       FICTION  ISSUE 180  September 2021
# 7   NON-FICTION  ISSUE 180  September 2021
# 8   NON-FICTION  ISSUE 180  September 2021
# 9   NON-FICTION  ISSUE 180  September 2021
# 10  NON-FICTION  ISSUE 180  September 2021
# 11    COVER ART  ISSUE 180  September 2021
#
#                                                 title  \
# 0                                    Yesterday's Wolf
# 1                     It is a Pleasure to Receive You
# 2                         Xiaolongbao: Soup Dumplings
# 3                                   Dog and Pony Show
# 4                                   The Winter Garden
# 5                    In a Net I Seek to Hold the Wind
# 6   Excerpts from the Text of an Explanatory Stele...
# 7                  Under Pressure: Life's Last Dance?
# 8   The Practice of Writing: A Conversation with N...
# 9    5,000 Words a Day: A Conversation with Cat Rambo
# 10           Editor's Desk: Ten+ Years of Translation
# 11                                             Vimana
#
#                                            byline  \
# 0                                   by Ray Nayler
# 1                                 by Ziggy Schutz
# 2                          by D.A. Xiaolin Spires
# 3                             by Robert Jeschonek
# 4   by Regina Kanyu Wang, translated by Emily Jin
# 5                               by Gregory Feeley
# 6                                by Timons Esaias
# 7                               by Julie Nováková
# 8                                   by Arley Sorg
# 9                                   by Arley Sorg
# 10                                 by Neil Clarke
# 11                                 by Daniele Gay
#
#                                                  link
# 0       https://clarkesworldmagazine.com/nayler_09_21
# 1       https://clarkesworldmagazine.com/schutz_09_21
# 2       https://clarkesworldmagazine.com/spires_09_21
# 3    https://clarkesworldmagazine.com/jeschonek_09_21
# 4         https://clarkesworldmagazine.com/wang_09_21
# 5       https://clarkesworldmagazine.com/feeley_09_21
# 6       https://clarkesworldmagazine.com/esaias_09_21
# 7     https://clarkesworldmagazine.com/novakova_09_21
# 8    https://clarkesworldmagazine.com/allan_interview
# 9   https://clarkesworldmagazine.com/rambo_intervi...
# 10      https://clarkesworldmagazine.com/clarke_09_21
# 11        https://clarkesworldmagazine.com/artbio_180

# %%
filename = 'clarkesworld/stories.csv'

# df.to_csv(filename, index=False)

# %% [markdown]
# ## Auto-updating scraper `3 points`
#
# Using GitHub Actions, implement a scraper that will keep track of everything posted to the Clarkesworld homepage. For example, when issue 181 comes out it should *add to the CSV* instead of just replacing it.
#
# > Tip: `drop_duplicates` might save you a lot of effort at one point or another.

# %%
pd.read_csv(filename).append(df).drop_duplicates().to_csv(filename, index=False)
