# %% [markdown]
# # Regression and Feature Importance with the Boston Globe
#
# Based on the super-old but super-relevant [Speed Trap: Who Gets a Ticket, Who Gets a Break?](http://archive.boston.com/globe/metro/packages/tickets/).
#
# For data, we'll be using `tickets-warnings.csv`.
#
# If you'd like to kind of ignore everything I say, you can go read [this page](https://investigate.ai/boston-globe-tickets/boston-globe-ticketing-regression/). It assumes some prior knowledge of logistic regression and the `statsmodels` package, though - we're coming into this backwards since we began with sentiment analysis!

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 100)

# %%
# Unknown data is always coded as 'U', so we'll pass that to na_values
df = pd.read_csv('tickets-warnings.csv', na_values='U')
df.head(2)
# Out:
#   TYPE  CITATION      DATE        DOW                  AGENCY       AGENCY2  \
# 0    T  K0001506  20010411  Wednesday  State Police Troop A-4  State Police
# 1    T  K0001507  20010417    Tuesday  State Police Troop A-4  State Police
#
#   AGENCY3 LOCAL       OFFICER LICSTATE CLASS CDL RACE MINORITY  BLACK  ASIAN  \
# 0       S     N  8.247791e+15       MA     D   N    W        W    0.0    0.0
# 1       S     N  8.247791e+15       MA     D   N    W        W    0.0    0.0
#
#    HISPANIC  MIDDLE  NATIVE SEX  FEMALE SEARCH  SEARCH2     LOCATE2  \
# 0       0.0     0.0     0.0   M     0.0    NaN      NaN      Woburn
# 1       0.0     0.0     0.0   F     1.0    NaN      NaN  Somerville
#
#      LOCATION  TIME AMPM       TIEMDAY DAYNIGHT  DAY           DESCRIPT  \
# 0      Woburn     5   PM  b) afternoon      day    1           SPEEDING
# 1  Somerville    10   AM    a) morning      day    1  TRAFFIC VIOLATION
#
#    AMOUNT  MPH  ZONE  MPHOVER  MPHPCT     MPHGROUP   YOB   AGE AGEGROUP  \
# 0   125.0   80    65     15.0    23.0  b) 10 to 15  1980  21.0    21-25
# 1    50.0    0     0      NaN     NaN          NaN  1965  36.0    36-40
#
#   AGEBAND     ZIP          NEIGHBOR INNEIGH REGSTATE V_MAKE V_TYPE  V_YEAR  \
# 0   16-25  1876.0               NaN     NaN       MA    NaN    NaN       0
# 1   26-39  2135.0  Allston-Brighton       N       MA   DODG  ARIES    1988
#
#    V_AGE V_AGEGRP  COLOR HOMESTATE   HOMETOWN INTOWN INSTATE  INTOWN2  \
# 0    NaN      NaN    NaN        MA  Tewksbury      N       Y      0.0
# 1   13.0    older  WHITE        MA     Boston      N       Y      0.0
#
#    INSTATE2
# 0         1
# 1         1

# %%
df.TYPE.value_counts()
# Out:
# T    84002
# W    82366
# Name: TYPE, dtype: int64

# %%
df = df[['TYPE','AGENCY3','SEX','BLACK','ASIAN','HISPANIC','MINORITY','AGE','MPH','MPHOVER','INTOWN', 'INSTATE', 'DAYNIGHT']].copy()
df.head()
# Out:
#   TYPE AGENCY3 SEX  BLACK  ASIAN  HISPANIC MINORITY   AGE  MPH  MPHOVER  \
# 0    T       S   M    0.0    0.0       0.0        W  21.0   80     15.0
# 1    T       S   F    0.0    0.0       0.0        W  36.0    0      NaN
# 2    T       S   F    0.0    0.0       0.0        W  61.0    0      NaN
# 3    T       S   M    0.0    0.0       0.0        W  52.0    0      NaN
# 4    T       S   M    0.0    0.0       0.0        W  24.0   85     20.0
#
#   INTOWN INSTATE DAYNIGHT
# 0      N       Y      day
# 1      N       Y      day
# 2      N       N      day
# 3      N       N    night
# 4      N       Y      day

# %%
print(df.shape)
df = df.dropna().copy()
print(df.shape)
# Out:
# (89691, 16)
# (89691, 16)

# %%
# TYPE
# T = ticket
# W = warning
df['is_ticketed'] = df.TYPE.replace({
    'T': 1,
    'W': 0
})
df.head()
# Out:
#   TYPE AGENCY3 SEX  BLACK  ASIAN  HISPANIC MINORITY   AGE  MPH  MPHOVER  \
# 0    T       S   M    0.0    0.0       0.0        W  21.0   80     15.0
# 4    T       S   M    0.0    0.0       0.0        W  24.0   85     20.0
# 5    T       S   M    0.0    0.0       0.0        W  37.0   80     30.0
# 6    W       S   M    0.0    0.0       0.0        W  30.0   80     15.0
# 7    W       S   F    1.0    0.0       0.0        M  22.0   75     10.0
#
#   INTOWN INSTATE DAYNIGHT  is_ticketed  is_male  is_white
# 0      N       Y      day            1      1.0       1.0
# 4      N       Y      day            1      1.0       1.0
# 5      N       Y      day            1      1.0       1.0
# 6      N       N    night            0      1.0       1.0
# 7      N       N    night            0      0.0       0.0

# %%
df['is_male'] = df.SEX.replace({
    'M': 1,
    'F': 0
})
df.head(2)
# Out:
#   TYPE AGENCY3 SEX  BLACK  ASIAN  HISPANIC MINORITY   AGE  MPH  MPHOVER  \
# 0    T       S   M    0.0    0.0       0.0        W  21.0   80     15.0
# 4    T       S   M    0.0    0.0       0.0        W  24.0   85     20.0
#
#   INTOWN INSTATE DAYNIGHT  is_ticketed  is_male  is_white
# 0      N       Y      day            1        1       1.0
# 4      N       Y      day            1        1       1.0

# %%
df['is_white'] = df.MINORITY.replace({
    'W': 1,
    'M': 0
})
df.head(2)
# Out:
#   TYPE AGENCY3 SEX  BLACK  ASIAN  HISPANIC MINORITY   AGE  MPH  MPHOVER  \
# 0    T       S   M    0.0    0.0       0.0        W  21.0   80     15.0
# 4    T       S   M    0.0    0.0       0.0        W  24.0   85     20.0
#
#   INTOWN INSTATE DAYNIGHT  is_ticketed  is_male  is_white
# 0      N       Y      day            1        1         1
# 4      N       Y      day            1        1         1

# %%
df['is_intown'] = df.INTOWN.replace({
    'Y': 1,
    'N': 0
})
df.head(2)
# Out:
#   TYPE AGENCY3 SEX  BLACK  ASIAN  HISPANIC MINORITY   AGE  MPH  MPHOVER  \
# 0    T       S   M    0.0    0.0       0.0        W  21.0   80     15.0
# 4    T       S   M    0.0    0.0       0.0        W  24.0   85     20.0
#
#   INTOWN INSTATE DAYNIGHT  is_ticketed  is_male  is_white  is_intown
# 0      N       Y      day            1        1         1          0
# 4      N       Y      day            1        1         1          0

# %%
feature_columns = ['is_male', 'is_white', 'is_intown']
X = df[feature_columns]
y = df.is_ticketed

# %%
X.head(3)
# Out:
#    is_male  is_white  is_intown
# 0        1         1          0
# 4        1         1          0
# 5        1         1          0

# %%
y[:3]
# Out:
# 0    1
# 4    1
# 5    1
# Name: is_ticketed, dtype: int64

# %% [markdown]
# ## Classification
#
# "What is going on in minds of the police??????"
#
# Let's make a model that reproduces what the police do, but with machine learning!

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=2)

clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
import eli5

feature_names = list(X.columns)

eli5.show_weights(clf,
                  feature_names=feature_names,
                  target_names=['warning', 'ticket'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.6431
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_intown
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1960
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_male
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1609
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 is_white
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <br>
#         <pre><svg width="626pt" height="314pt"
#  viewBox="0.00 0.00 626.00 314.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 310)">
# <title>Tree</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-310 622,-310 622,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <polygon fill="none" stroke="black" points="379,-306 238,-306 238,-223 379,-223 379,-306"/>
# <text text-anchor="middle" x="308.5" y="-290.8" font-family="Times,serif" font-size="14.00">is_intown &lt;= 0.5</text>
# <text text-anchor="middle" x="308.5" y="-275.8" font-family="Times,serif" font-size="14.00">gini = 0.499</text>
# <text text-anchor="middle" x="308.5" y="-260.8" font-family="Times,serif" font-size="14.00">samples = 100.0%</text>
# <text text-anchor="middle" x="308.5" y="-245.8" font-family="Times,serif" font-size="14.00">value = [0.476, 0.524]</text>
# <text text-anchor="middle" x="308.5" y="-230.8" font-family="Times,serif" font-size="14.00">class = ticket</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <polygon fill="none" stroke="black" points="300,-187 159,-187 159,-104 300,-104 300,-187"/>
# <text text-anchor="middle" x="229.5" y="-171.8" font-family="Times,serif" font-size="14.00">is_male &lt;= 0.5</text>
# <text text-anchor="middle" x="229.5" y="-156.8" font-family="Times,serif" font-size="14.00">gini = 0.492</text>
# <text text-anchor="middle" x="229.5" y="-141.8" font-family="Times,serif" font-size="14.00">samples = 76.0%</text>
# <text text-anchor="middle" x="229.5" y="-126.8" font-family="Times,serif" font-size="14.00">value = [0.437, 0.563]</text>
# <text text-anchor="middle" x="229.5" y="-111.8" font-family="Times,serif" font-size="14.00">class = ticket</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M281.09,-222.91C275.09,-214.01 268.67,-204.51 262.47,-195.33"/>
# <polygon fill="black" stroke="black" points="265.36,-193.35 256.86,-187.02 259.56,-197.27 265.36,-193.35"/>
# <text text-anchor="middle" x="252.1" y="-207.86" font-family="Times,serif" font-size="14.00">True</text>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <polygon fill="none" stroke="black" points="445,-187 332,-187 332,-104 445,-104 445,-187"/>
# <text text-anchor="middle" x="388.5" y="-171.8" font-family="Times,serif" font-size="14.00">is_white &lt;= 0.5</text>
# <text text-anchor="middle" x="388.5" y="-156.8" font-family="Times,serif" font-size="14.00">gini = 0.48</text>
# <text text-anchor="middle" x="388.5" y="-141.8" font-family="Times,serif" font-size="14.00">samples = 24.0%</text>
# <text text-anchor="middle" x="388.5" y="-126.8" font-family="Times,serif" font-size="14.00">value = [0.6, 0.4]</text>
# <text text-anchor="middle" x="388.5" y="-111.8" font-family="Times,serif" font-size="14.00">class = warning</text>
# </g>
# <!-- 0&#45;&gt;4 -->
# <g id="edge4" class="edge">
# <title>0&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M336.26,-222.91C342.34,-214.01 348.84,-204.51 355.11,-195.33"/>
# <polygon fill="black" stroke="black" points="358.04,-197.25 360.79,-187.02 352.26,-193.3 358.04,-197.25"/>
# <text text-anchor="middle" x="365.41" y="-207.89" font-family="Times,serif" font-size="14.00">False</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <polygon fill="none" stroke="black" points="141,-68 0,-68 0,0 141,0 141,-68"/>
# <text text-anchor="middle" x="70.5" y="-52.8" font-family="Times,serif" font-size="14.00">gini = 0.5</text>
# <text text-anchor="middle" x="70.5" y="-37.8" font-family="Times,serif" font-size="14.00">samples = 28.4%</text>
# <text text-anchor="middle" x="70.5" y="-22.8" font-family="Times,serif" font-size="14.00">value = [0.494, 0.506]</text>
# <text text-anchor="middle" x="70.5" y="-7.8" font-family="Times,serif" font-size="14.00">class = ticket</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge2" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M170.29,-103.73C156.18,-94.01 141.16,-83.66 127.16,-74.02"/>
# <polygon fill="black" stroke="black" points="128.82,-70.91 118.6,-68.13 124.85,-76.68 128.82,-70.91"/>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <polygon fill="none" stroke="black" points="300,-68 159,-68 159,0 300,0 300,-68"/>
# <text text-anchor="middle" x="229.5" y="-52.8" font-family="Times,serif" font-size="14.00">gini = 0.481</text>
# <text text-anchor="middle" x="229.5" y="-37.8" font-family="Times,serif" font-size="14.00">samples = 47.6%</text>
# <text text-anchor="middle" x="229.5" y="-22.8" font-family="Times,serif" font-size="14.00">value = [0.403, 0.597]</text>
# <text text-anchor="middle" x="229.5" y="-7.8" font-family="Times,serif" font-size="14.00">class = ticket</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g id="edge3" class="edge">
# <title>1&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M229.5,-103.73C229.5,-95.52 229.5,-86.86 229.5,-78.56"/>
# <polygon fill="black" stroke="black" points="233,-78.3 229.5,-68.3 226,-78.3 233,-78.3"/>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <polygon fill="none" stroke="black" points="459,-68 318,-68 318,0 459,0 459,-68"/>
# <text text-anchor="middle" x="388.5" y="-52.8" font-family="Times,serif" font-size="14.00">gini = 0.494</text>
# <text text-anchor="middle" x="388.5" y="-37.8" font-family="Times,serif" font-size="14.00">samples = 4.2%</text>
# <text text-anchor="middle" x="388.5" y="-22.8" font-family="Times,serif" font-size="14.00">value = [0.446, 0.554]</text>
# <text text-anchor="middle" x="388.5" y="-7.8" font-family="Times,serif" font-size="14.00">class = ticket</text>
# </g>
# <!-- 4&#45;&gt;5 -->
# <g id="edge5" class="edge">
# <title>4&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M388.5,-103.73C388.5,-95.52 388.5,-86.86 388.5,-78.56"/>
# <polygon fill="black" stroke="black" points="392,-78.3 388.5,-68.3 385,-78.3 392,-78.3"/>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <polygon fill="none" stroke="black" points="618,-68 477,-68 477,0 618,0 618,-68"/>
# <text text-anchor="middle" x="547.5" y="-52.8" font-family="Times,serif" font-size="14.00">gini = 0.465</text>
# <text

# %% [markdown]
# ## Let's try another classifier!

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(C=1e9, solver='lbfgs')

clf.fit(X, y)
# Out:
# LogisticRegression(C=1000000000.0)

# %%
import eli5

feature_names = list(X.columns)

eli5.show_weights(clf, feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.390
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.364
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         is_male
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.414
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         is_white
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.668
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         is_intown
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
