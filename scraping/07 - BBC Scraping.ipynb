# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get("https://www.bbc.com/")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
stories = doc.select('.media-list__item')

# %%
# find everything with the class of media-list__item
# each one of these is going to be a row

# Starting off without ANY rows
rows = []

for story in stories:
    print("----")
    # Starting off knowing NONE of the columns of data for this datapoint?
    row = {}

    row['title'] = story.select_one('h3').text.strip()

    try:
        # Find me a media__link OR a reel_link
        row['href'] = story.select_one('.media__link, .reel__link')['href']
    except:
        print("Couldn't find a link")

    try:
        row['tag'] = story.select_one('.media__tag').text.strip()
    except:
        print("Couldn't find a tag!")

    try:
        row['summary'] = story.select_one('.media__summary').text.strip()
    except:
        print("Couldn't find a summary")

    print(row)
    # When we're done adding info to our row, we're going to add it into our list
    # of rows
    rows.append(row)
# Out:
# ----
# {'title': 'US to evacuate endangered Afghan translators', 'href': '/news/world-asia-57844294', 'tag': 'Asia', 'summary': 'The Biden administration is to evacuate Afghan translators who assisted them during the war.'}
# ----
# Couldn't find a summary
# {'title': 'FBI failed to investigate USA Gymnastics abuser', 'href': 'https://www.bbc.com/news/world-us-canada-57844784', 'tag': 'US'}
# ----
# Couldn't find a summary
# {'title': 'Chinese engineers killed in Pakistan bus blast', 'href': 'https://www.bbc.com/news/world-asia-57837072', 'tag': 'Asia'}
# ----
# Couldn't find a summary
# {'title': 'Messi agrees Barca stay on reduced wages', 'href': '/sport/football/57836300', 'tag': 'European Football'}
# ----
# Couldn't find a summary
# {'title': 'Do you still have to dress up for work?', 'href': 'https://www.bbc.com/worklife/article/20210713-is-the-formal-suited-and-booted-office-dress-code-extinct', 'tag': 'Worklife'}
# ----
# {'title': 'Fleeing bombs and bullets in Afghanistan', 'href': '/news/world-asia-57841719', 'tag': 'Asia', 'summary': "Yogita Limaye reports from Afghanistan's strategic Kunduz province, mainly now in Taliban hands."}
# ----
# {'title': 'Britney Spears can hire own lawyer, judge rules', 'href': '/news/world-us-canada-57839526', 'tag': 'US & Canada', 'summary': 'The decision comes as the pop star addresses a US court for the second time in less than a month.'}
# ----
# {'title': 'Cuba lifts customs restrictions after unrest', 'href': '/news/world-latin-america-57844864', 'tag': 'Latin America & Caribbean', 'summary': 'Following recent protests, import duties on food and medicine are lifted for travellers to Cuba.'}
# ----
# {'title': "'It was a double life - you could be killed any moment'", 'href': '/sport/athletics/57656659', 'tag': 'Athletics', 'summary': 'As Darren Campbell emerged as a talented teenage sprinter, he was leading a double life as a gang member. A twist of fate broke him free.'}
# ----
# {'title': 'Pogacar wins stage 17 to extend lead', 'href': '/sport/cycling/57840945', 'tag': 'Cycling', 'summary': 'Defending champion Tadej Pogacar takes a sublime victory atop the Col du Portet on stage 17 of the Tour de France to extend his lead in the yellow jersey.'}
# ----
# {'title': 'South Africa A inflict Lions first loss', 'href': '/sport/rugby-union/57841466', 'tag': 'Rugby Union', 'summary': "South Africa A inflict the 2021 British and Irish Lions' first defeat to serve up a sobering reminder of what awaits in the three-Test series."}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': "Unlocking the ancient secrets of the world's oldest computer", 'href': '/reel/video/p09pcwnz/unlocking-the-secrets-of-the-world-s-oldest-computer'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': "An expert's guide to being happy", 'href': '/reel/video/p09p3wx1/an-expert-s-guide-to-finding-happiness'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The surprising psychology behind being rich', 'href': '/reel/video/p07vts5j/the-surprising-psychology-behind-being-rich'}
# ----
# {'title': 'What your sneakers say about you', 'href': 'https://www.bbc.com/culture/article/20210714-what-your-sneakers-say-about-you', 'tag': 'Culture', 'summary': 'For sneakerheads there is a style of trainer for every taste and identity'}
# ----
# {'title': "The entrancing power of 'song maps'", 'href': 'https://www.bbc.com/future/article/20210714-why-local-legends-about-birds-matter', 'tag': 'Future', 'summary': 'Indigenous stories about birds contain information too valuable to be lost'}
# ----
# {'title': 'How the future of offices will look', 'href': 'https://www.bbc.com/worklife/article/20210713-hybrid-work-what-the-office-could-look-like-now', 'tag': 'Worklife', 'summary': 'With hybrid jobs, work looks different now – so the office will, too'}
# ----
# {'title': "One of Europe's last wild bastions", 'href': 'https://www.bbc.com/travel/article/20210714-transcaucasian-trail-a-new-route-between-europe-and-asia', 'tag': 'Travel', 'summary': 'The Transcaucasian Trail will soon allow walkers to trek from Europe to Asia'}
# ----
# {'title': "Baron Cohen prevails in politician's legal battle", 'href': 'https://www.bbc.com/news/entertainment-arts-57833093', 'tag': 'Entertainment & Arts', 'summary': 'Roy Moore loses his attempt to sue comedian Sacha Baron Cohen, who duped him on his TV show'}
# ----
# {'title': 'Ex-Nissan boss Ghosn: How I escaped Japan in a box', 'href': 'https://www.bbc.com/news/business-57760993', 'tag': 'Business', 'summary': 'The former boss of Nissan and Renault reveals how evaded house arrest to flee to Lebanon'}
# ----
# {'title': 'The Crown and Mandalorian lead Emmy nominations', 'href': 'https://www.bbc.com/news/entertainment-arts-57806729', 'tag': 'Entertainment & Arts', 'summary': 'Both shows have 24 nominations apiece, other series recognised include WandaVision and Pose'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': "The beavers returning to Utah's desert", 'href': '/future/article/20210713-the-beavers-returning-to-the-desert'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The new use for abandoned coal mines', 'href': '/future/article/20210706-how-flooded-coal-mines-could-heat-homes'}
# ----
# Couldn't find a tag!
# Couldn't find a summary
# {'title': 'The tree boosting Brazilan beef', 'href': '/future/article/20210629-the-australian-tree-cutting-brazilian-beefs-emissions'}
# ----
# {'title': "MPs call for 'complete reset' of music streaming", 'href': '/news/entertainment-arts-57838473', 'tag': 'Entertainment & Arts', 'summary': 'The music industry is weighted against artists, who see "pitiful returns" from streaming, MPs say.'}
# ----
# Couldn't find a summary
# {'title': "Nasa set for attempt to fix Hubble's trouble", 'href': '/news/science-environment-57844454', 'tag': 'Science & Environment'}
# ----
# Couldn't find a summary
# {'title': 'Microsoft announces subscription cloud PC service', 'href': '/news/technology-57836326', 'tag': 'Technology'}
# ----
# Couldn't find a summary
# {'title': 'Sydney extends lockdown to fight Delta outbreak', 'href': '/news/world-australia-57832211', 'tag': 'Australia'}
# ----
# Couldn't find a summary
# {'title': 'Carry on flying, says government green plan', 'href': '/news/business-57830168', 'tag': 'Business'}
# ----
# Couldn't find a summary
# {'title': 'Why Covid has jacked up used car prices', 'href': '/news/business-57809849', 'tag': 'Business'}
# ----
# Couldn't find a summary
# {'title': "Debbie Harry on Blondie's 'monumental' Cuba trip", 'href': '/news/entertainment-arts-57808649', 'tag': 'Entertainment & Arts'}
# ----
# Couldn't find a summary
# {'title': 'A pandemic constitutional in pictures', 'href': '/news/in-pictures-57819761', 'tag': 'In Pictures'}
# ----
# Couldn't find a summary
# {'title': 'The messages of pride and positivity for Rashford', 'href': '/news/uk-england-manchester-57819446', 'tag': 'Manchester'}
# ----
# Couldn't find a summary
# {'title': 'How England fans went from joy to sorrow', 'href': '/news/in-pictures-57796519', 'tag': 'In Pictures'}
# ----
# Couldn't find a summary
# {'title': 'Exhibition reveals people behind rare illnesses', 'href': '/news/uk-wales-57748393', 'tag': 'Wales'}
# ----
# Couldn't find a summary
# {'title': 'Photographer shows the authentic face of black Britain', 'href': '/news/entertainment-arts-57733386', 'tag': 'Entertainment & Arts'}

# %%
df = pd.DataFrame(rows)
df
# Out:
#                                                 title  \
# 0        US to evacuate endangered Afghan translators
# 1     FBI failed to investigate USA Gymnastics abuser
# 2      Chinese engineers killed in Pakistan bus blast
# 3            Messi agrees Barca stay on reduced wages
# 4             Do you still have to dress up for work?
# 5            Fleeing bombs and bullets in Afghanistan
# 6     Britney Spears can hire own lawyer, judge rules
# 7        Cuba lifts customs restrictions after unrest
# 8   'It was a double life - you could be killed an...
# 9                Pogacar wins stage 17 to extend lead
# 10            South Africa A inflict Lions first loss
# 11  Unlocking the ancient secrets of the world's o...
# 12                   An expert's guide to being happy
# 13        The surprising psychology behind being rich
# 14                   What your sneakers say about you
# 15                The entrancing power of 'song maps'
# 16                How the future of offices will look
# 17                 One of Europe's last wild bastions
# 18  Baron Cohen prevails in politician's legal battle
# 19  Ex-Nissan boss Ghosn: How I escaped Japan in a...
# 20    The Crown and Mandalorian lead Emmy nominations
# 21             The beavers returning to Utah's desert
# 22               The new use for abandoned coal mines
# 23                    The tree boosting Brazilan beef
# 24   MPs call for 'complete reset' of music streaming
# 25       Nasa set for attempt to fix Hubble's trouble
# 26  Microsoft announces subscription cloud PC service
# 27    Sydney extends lockdown to fight Delta outbreak
# 28        Carry on flying, says government green plan
# 29            Why Covid has jacked up used car prices
# 30   Debbie Harry on Blondie's 'monumental' Cuba trip
# 31              A pandemic constitutional in pictures
# 32  The messages of pride and positivity for Rashford
# 33           How England fans went from joy to sorrow
# 34    Exhibition reveals people behind rare illnesses
# 35  Photographer shows the authentic face of black...
#
#                                                  href  \
# 0                           /news/world-asia-57844294
